# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("National_Daily_Deaths.csv") #Läser in filen med hjälp av pandas

dag = df["Date"][1:340]

antal_döda= df["National_Daily_Deaths"][1:340]

plt.plot(dag, antal_döda)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Gender_Data.csv") #Läser in filen med hjälp av pandas
smittade = df["Total_Cases"]
färg = ["blue", "pink"]
döda = df["Total_Deaths"]
a = np.linspace(-np.pi, np.pi)

def cirkel(x,y):
    plt.pie(x, labels=y, autopct='%1.1f%%', colors=färg)
    plt.axis('equal')
    plt.title("Antal smittade bland könen")
    plt.show()
cirkel(smittade,smittade)
plt.subplot(1,2,1)
plt.plot(a,cirkel)

def cirkel(x,y):
    plt.pie(x, labels=y, autopct='%1.1f%%', colors=färg)
    plt.axis('equal')
    plt.title("Antal döda bland könen")
    plt.show()
cirkel(döda,döda)
plt.subplot(1,2,2)
plt.plot(a,cirkel)

def graf(x,y):
    plt.bar(x, y, width=0.5, alpha=1, color=färg)
    plt.xticks(x,y)
    plt.ylabel("Antalet i miljoner")
    plt.title("Antalet som blivit smittade och hur många som dött")
    plt.show()
graf(smittade,smittade)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-bdc5f5c2e081> in <module>
#      15 cirkel(smittade,smittade)
#      16 plt.subplot(1,2,1)
# ---> 17 plt.plot(a,cirkel)
#      18
#      19 def cirkel(x,y):
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Gender_Data.csv") #Läser in filen med hjälp av pandas
df
# Out:
#    Gender  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 0    Male       288507                  3582          6657
# 1  Female       319641                  1411          5771

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Gender_Data.csv") #Läser in filen med hjälp av pandas
smittade = df["Total_Cases"]
färg = ["blue", "pink"]
döda = df["Total_Deaths"]

def graf(x,y):
    plt.subplots()
    plt.pie(x, labels=y, autopct='%1.1f%%', colors=färg)
    plt.axis('equal')
    plt.title("Antal döda bland könen")
    plt.show()
graf(döda,döda)

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.linspace(-np.pi, np.pi)

plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,np.cos(x))
